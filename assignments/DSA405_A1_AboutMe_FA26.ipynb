# %% [markdown]
# # A1 — About Me, Your Data Interests & Skills Self-Check
#
# **DSA 405 · Week 1**
#
# | | |
# |---|---|
# | **Assigned** | Friday, Aug 21 |
# | **A1 due** | Thursday, Aug 27, 11:59 PM |
# | **Also due Thu Aug 27** | **P0** Workspace (separate handout) |
# | **Time** | ~45–60 min, including the reading |

# %% [markdown]
# ---
# ## Task 1 — About you
#
# Answer in this cell. Two or three sentences each is plenty.
#
# 1. **Name, unity ID, and what you're studying.**
# 2. **Your programming history, honestly.** Languages, how recent, how confident. "R-fluent,
#    Python twice, two years ago" is a perfectly good answer.
# 3. **A dataset you actually care about.** Not one you think sounds academic — one you would
#    look at on a Saturday. Sports, music, transit, games, campus food. Name it specifically.
# 4. **One thing you want to be able to do by Week 14** that you cannot do now.
#
# *Your answers.*

# %% [markdown]
# ## Task 2 — Skills Self-Check result
#
# Run `DSA405_SkillsSelfCheck_FA26.ipynb` (posted with the Week 0 material, ~20 minutes),
# then report the result below. The number is not graded — a 3/13 and a 13/13 earn identical
# credit here. What I do with it: if half the room misses the comprehension tasks, Week 2
# slows down; if nobody does, it doesn't.
#
# If the notebook pointed you at the Bridge, say whether you plan to do it before Week 2.

# %%
self_check_score = ...        # your count out of 13
group = "..."                 # the group the notebook printed (1, 2, or 3)

print(f"self-check: {self_check_score}/13, group {group}")

# %% [markdown]
# ## Task 3 — Audit the 80% claim
#
# You will hear, everywhere and forever, that *"data scientists spend 80% of their time
# cleaning data."* In class we asked where that number comes from. Now go find out.
#
# Read **[R1] McKinney, ch. 1** (8 pp., free at wesmckinney.com/book) for how the author
# frames data preparation inside the workflow. Then hunt the 80% claim itself: find the most
# primary source you can — not a blog post quoting a listicle quoting a survey, but the
# survey. Who counted, when, how many people did they ask, and what exactly did they lump
# under "cleaning"?
#
# Write **two short paragraphs**:
#
# 1. **What you found.** The best source you could locate, with a link, and the number *it*
#    actually reports — which may not be 80.
# 2. **Your verdict.** Given who counted and how, how much should anyone trust the claim?
#    One sentence on what it would take to measure it properly.
#
# This is the course's whole method in miniature: the answer "it runs and everyone repeats
# it" is not the same as "it's right."
#
# *Your two paragraphs.*

# %% [markdown]
# ## Task 4 — Three project sparks
#
# The project (55% of your grade — see the specification and tier descriptions posted this
# week) starts from *your* question about *your* data. You don't commit to anything until P1
# (due Thu Sep 3). Right now I want three **candidate directions**, one line each:
#
# > the question + where the data might come from
#
# Example: *"Have Wake County restaurant scores drifted over five years? — county open-data
# portal."* Rough is fine; two of these will die and that's their job. You'll post your three
# to the **Week 2 forum** before class on Aug 28, so do the thinking here.
#
# *Your three, one line each.*

# %% [markdown]
# ## Task 5 — The AI ground rules, in your own words
#
# Read the syllabus section **"AI Use Policy."** Then answer, one or
# two sentences each:
#
# 1. What are the three things the policy asks of you?
# 2. At a Bench Check, what must you be able to do with code you submitted?
# 3. What is the honest thing to write in an AI-use note if you used no AI at all?
#
# *Your answers.*

# %% [markdown]
# ---
# ## AI use note
#
# Which tools did you use on A1, and for what? If none, write "none." One or two sentences.
# (Task 5 explains why this box is on everything.)
#
# *Your answer.*

# %% [markdown]
# ---
# ## Submitting
#
# 1. **Runtime > Restart runtime**, then **Run all** — the one code cell should print your
#    self-check line without errors.
# 2. `File > Download > Download .ipynb`
# 3. Rename to `DSA405_001_FA26_A1_[yourUnityID].ipynb`
# 4. Upload to the **A1** space on Moodle by **Thursday, Aug 27, 11:59 PM**.
#
# **P0** (workspace setup) is due the same night, as a separate submission — its handout is
# `DSA405_P0_Workspace_FA26.md`.
